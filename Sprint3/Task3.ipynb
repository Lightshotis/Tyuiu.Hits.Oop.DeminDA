// %% [markdown]
// <h1 style="color:DodgerBlue">Индивидальный проект</h1>

// %% [markdown]
// <h2 style="color:DodgerBlue">Название проекта:</h2>
//
// ----
//
// ### Вариант задания  5

// %% [markdown]
// <h2 style="color:DodgerBlue">Описание проекта:</h2>
//
// ----
//
// [ваш текст]
//
// #### Дополнительное задание
// Добавьте к сущестующим классам (базовыму и производным 3-4 атрибута и метода) и реализуйте полиморфизм с перекрытием и прегегрузкой методов, а также generic классы

// %% [markdown]
// <h2 style="color:DodgerBlue">Реализация:</h2>
//
// ----

// %%
using System;
using System.Collections.Generic;

// Интерфейс для книг, которые можно брать
public interface IBorrowable
{
    string Borrow();
    string Return();
}

// Интерфейс для книг, которые можно читать
public interface IReadable
{
    string Read();
}

// Базовый класс Book
public class Book
{
    // Атрибуты
    public string Title { get; set; }
    public string Author { get; set; }
    public int YearOfPublication { get; set; }
    public string Publisher { get; set; }
    public int Pages { get; set; }
    public bool IsAvailable { get; set; }
    public string Language { get; set; }  // Новый атрибут
    public string ISBN { get; set; }      // Новый атрибут

    // Конструктор
    public Book(string title, string author, int yearOfPublication, string publisher, int pages, string language, string isbn)
    {
        Title = title;
        Author = author;
        YearOfPublication = yearOfPublication;
        Publisher = publisher;
        Pages = pages;
        IsAvailable = true;
        Language = language;
        ISBN = isbn;
    }

    // Методы
    public virtual string GetInfo()
    {
        return $"Название: {Title}\nАвтор: {Author}\nГод публикации: {YearOfPublication}\nИздатель: {Publisher}\nСтраницы: {Pages}\nЯзык: {Language}\nISBN: {ISBN}";
    }

    public string Reserve()
    {
        if (IsAvailable)
        {
            IsAvailable = false;
            return "Книга зарезервирована.";
        }
        return "Книга уже зарезервирована.";
    }

    public string ReturnBook()
    {
        IsAvailable = true;
        return "Книга возвращена.";
    }

    public string CheckAvailability()
    {
        return IsAvailable ? "Книга доступна." : "Книга недоступна.";
    }

    // Перегруженный метод
    public virtual string Read(int startPage, int endPage)
    {
        return $"Вы читаете страницы {startPage} по {endPage}.";
    }
}

// Производный класс TextBook (Учебник)
public class TextBook : Book, IBorrowable, IReadable
{
    public string Subject { get; set; }
    public string GradeLevel { get; set; }
    public string School { get; set; }   // Новый атрибут

    // Конструктор
    public TextBook(string title, string author, int yearOfPublication, string publisher, int pages, string language, string isbn, string subject, string gradeLevel, string school)
        : base(title, author, yearOfPublication, publisher, pages, language, isbn)
    {
        Subject = subject;
        GradeLevel = gradeLevel;
        School = school;
    }

    // Переопределенный метод чтения
    public string Read()
    {
        return $"Вы читаете учебник по {Subject}.";
    }

    public string Borrow()
    {
        return "Вы взяли учебник.";
    }

    public string Return()
    {
        return "Вы вернули учебник.";
    }

    // Новый метод
    public string Study()
    {
        return $"Вы изучаете {Subject} на уровне {GradeLevel} в {School}.";
    }

    // Перегрузка метода
    public override string Read(int startPage, int endPage)
    {
        return $"Вы читаете учебник с {startPage} по {endPage} страницы, изучая {Subject}.";
    }
}

// Производный класс Fiction (Художественная литература)
public class Fiction : Book, IBorrowable
{
    public string Genre { get; set; }
    public string MainCharacter { get; set; }
    public bool IsSeries { get; set; }  // Новый атрибут

    // Конструктор
    public Fiction(string title, string author, int yearOfPublication, string publisher, int pages, string language, string isbn, string genre, string mainCharacter, bool isSeries)
        : base(title, author, yearOfPublication, publisher, pages, language, isbn)
    {
        Genre = genre;
        MainCharacter = mainCharacter;
        IsSeries = isSeries;
    }

    // Переопределенный метод взятия книги
    public string Borrow()
    {
        return $"Вы взяли книгу жанра {Genre}.";
    }

    public string Return()
    {
        return "Вы вернули художественную книгу.";
    }

    // Новый метод
    public string DescribeMainCharacter()
    {
        return $"Главный персонаж этой книги — {MainCharacter}.";
    }

    // Перегрузка метода
    public override string Read(int startPage, int endPage)
    {
        return $"Вы читаете художественное произведение с {startPage} по {endPage} страницы.";
    }
}

// Производный класс ScientificLiterature (Научная литература)
public class ScientificLiterature : Book, IReadable
{
    public string FieldOfScience { get; set; }
    public bool IsPeerReviewed { get; set; }
    public string Institution { get; set; }  // Новый атрибут

    // Конструктор
    public ScientificLiterature(string title, string author, int yearOfPublication, string publisher, int pages, string language, string isbn, string fieldOfScience, bool isPeerReviewed, string institution)
        : base(title, author, yearOfPublication, publisher, pages, language, isbn)
    {
        FieldOfScience = fieldOfScience;
        IsPeerReviewed = isPeerReviewed;
        Institution = institution;
    }

    // Переопределенный метод получения информации
    public override string GetInfo()
    {
        return $"{base.GetInfo()}\nНаучная область: {FieldOfScience}\nРецензируемая: {(IsPeerReviewed ? "Да" : "Нет")}\nУчреждение: {Institution}";
    }

    // Переопределенный метод чтения
    public string Read()
    {
        return $"Вы читаете научную литературу по {FieldOfScience}.";
    }

    // Новый метод
    public string ConductResearch()
    {
        return $"Вы проводите исследование в области {FieldOfScience} в {Institution}.";
    }
}

// Генерический класс для библиотеки
public class Library<T> where T : Book
{
    private List<T> books = new List<T>();

    public void AddBook(T book)
    {
        books.Add(book);
    }

    public void RemoveBook(T book)
    {
        books.Remove(book);
    }

    public void DisplayBooks()
    {
        foreach (var book in books)
        {
            Console.WriteLine(book.GetInfo());
            Console.WriteLine(book.CheckAvailability());
        }
    }
}

        TextBook mathBook = new TextBook("Математика для инженеров", "Джон Доу", 2020, "НаукаПресс", 350, "Английский", "123456789", "Математика", "Бакалавриат", "Инженерная школа");
Fiction novel = new Fiction("Тайна старого дома", "Элис Джонсон", 2018, "РоманПресс", 250, "Английский", "987654321", "Детектив", "Детектив Смит", true);
ScientificLiterature scienceBook = new ScientificLiterature("Квантовая механика", "Альберт Эйнштейн", 1925, "ФизикаПресс", 400, "Немецкий", "192837465", "Физика", true, "Принстонский университет");


        // Создаем библиотеку учебников
        Library<TextBook> textbookLibrary = new Library<TextBook>();
        textbookLibrary.AddBook(mathBook);

        // Создаем библиотеку художественной литературы
        Library<Fiction> fictionLibrary = new Library<Fiction>();
        fictionLibrary.AddBook(novel);

        // Создаем библиотеку научной литературы
        Library<ScientificLiterature> scienceLibrary = new Library<ScientificLiterature>();
        scienceLibrary.AddBook(scienceBook);

        // Демонстрация методов
        Console.WriteLine(mathBook.Study());
        Console.WriteLine(novel.DescribeMainCharacter());
        Console.WriteLine(scienceBook.ConductResearch());

        // Перегрузка метода Read()
        Console.WriteLine(mathBook.Read(10, 20));
        Console.WriteLine(novel.Read(30, 50));

        // Проверка библиотек
        Console.WriteLine("\nУчебники:");
        textbookLibrary.DisplayBooks();

        Console.WriteLine("\nХудожественная литература:");
        fictionLibrary.DisplayBooks();

        Console.WriteLine("\nНаучная литература:");
        scienceLibrary.DisplayBooks();
// Out:
// Вы изучаете Математика на уровне Бакалавриат в Инженерная школа.
// Главный персонаж этой книги — Детектив Смит.
// Вы проводите исследование в области Физика в Принстонский университет.
// Вы читаете учебник с 10 по 20 страницы, изучая Математика.
// Вы читаете художественное произведение с 30 по 50 страницы.
//
// Учебники:
// Название: Математика для инженеров
// Автор: Джон Доу
// Год публикации: 2020
// Издатель: НаукаПресс
// Страницы: 350
// Язык: Английский
// ISBN: 123456789
// Книга доступна.
//
// Художественная литература:
// Название: Тайна старого дома
// Автор: Элис Джонсон
// Год публикации: 2018
// Издатель: РоманПресс
// Страницы: 250
// Язык: Английский
// ISBN: 987654321
// Книга доступна.
//
// Научная литература:
// Название: Квантовая механика
// Автор: Альберт Эйнштейн
// Год публикации: 1925
// Издатель: ФизикаПресс
// Страницы: 400
// Язык: Немецкий
// ISBN: 192837465
// Научная область: Физика
// Рецензируемая: Да
// Учреждение: Принстонский университет
// ...
